# %% [markdown]
# # Data Analytics - Lab 1.

# %%
import numpy as np
np.__version__
# Out:
# '1.24.2'

# %% [markdown]
# ## Array generation

# %%
uniform_1d = np.random.uniform(0, 1, 1000)
normal_1d_0_1 = np.random.normal(0, 1, 1000)
normal_1d_0_10 = np.random.normal(0, 10, 1000)
try:
    beta_1d_0_0 = np.random.beta(0, 0, 1000)
except ValueError as e:
    print("Can't create a beta distribution with alpha=0: ", str(e))

beta_1d_1_1 = np.random.beta(1, 1, 1000)
beta_1d_2_2 = np.random.beta(2, 2, 1000)
beta_1d_3_9 = np.random.beta(3, 9, 1000)
normal_2d_cov1 = np.random.multivariate_normal([0, 0], [[1, 0], [0, 1]], 10000)
normal_2d_cov2 = np.random.multivariate_normal([0, 0], [[2, 1], [1, 2]], 10000)
# Out:
# Can't create a beta distribution with alpha=0:  a <= 0

# %% [markdown]
# ## Visualization

# %%
import seaborn

# %%
seaborn.displot(data=uniform_1d)

# %%
seaborn.displot(data=normal_1d_0_1)

# %%
seaborn.displot(data=normal_1d_0_10)

# %%
seaborn.displot(data=beta_1d_1_1)

# %%
seaborn.displot(data=beta_1d_2_2)

# %%
seaborn.displot(data=beta_1d_3_9)

# %%
from matplotlib import pyplot as plt
plot_n_2d_cov1 = plt.hist2d(normal_2d_cov1[:][0], normal_2d_cov1[:][1])

# %%
plot_n_2d_cov1_bin_100 = plt.hist2d(normal_2d_cov1[:][0], normal_2d_cov1[:][1], bins=5)

# %%
plot_n_2d_cov2 = plt.hist2d(normal_2d_cov2[:][0], normal_2d_cov2[:][1])

# %%
sb_plot_n_2d_cov1 = seaborn.displot(normal_2d_cov1)

# %%
plot_n_2d_cov1_bin_100 = plt.hist2d(normal_2d_cov1[:][0], normal_2d_cov1[:][1])

# %%
plot_n_2d_cov1_bin_100 = plt.hist2d(normal_2d_cov1[:][0], normal_2d_cov1[:][1], bins=5)

# %%
plot_n_2d_cov1_bin_100 = plt.hist2d(normal_2d_cov1[:][0], normal_2d_cov1[:][1], bins=10)

# %%
sb_plot_n_2d_cov1 = seaborn.displot(normal_2d_cov1)

# %% [markdown]
# ## More complex model

# %%
a = np.random.normal(2, 0.1, 1000)
b = np.random.normal(0.2, 0.2, 1000)
x = np.random.normal(0, 3, 1000)
sig = np.abs(np.random.normal(0, 1, 1000))
mu = a + b * x
y = np.random.normal(mu, sig)

idxs = np.abs(x)<6
cmplx_mdl = plt.plot(x, y, '.',
                     x[idxs], a[idxs]+b[idxs]*x[idxs], 'r.')
lgnd = plt.legend(("y(x)", "a+b*x"))
